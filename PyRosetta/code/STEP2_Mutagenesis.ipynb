# %% [markdown]
# ### **Before using this notebook, you need to run the `STEP1_Relaxation.ipynb` first.**

# %%
import os
import csv

from pyrosetta import init, pose_from_pdb
from pyrosetta.rosetta.core.scoring import get_score_function
from pyrosetta.rosetta.core.pack.task import TaskFactory, operation
from pyrosetta.rosetta.core.select.residue_selector import ResidueIndexSelector, NeighborhoodResidueSelector, NotResidueSelector
from pyrosetta.rosetta.protocols.minimization_packing import PackRotamersMover

# %%
def parse_mutation_file(file_path):
    """
    Parses a mutation file where each line contains: line_number mutation[ mutation ...]
    Returns:
        List of (line_number, mutation_dict) where mutation_dict maps PDB position to target AA.
    """
    mutations = []
    with open(file_path, 'r') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            parts = line.split()
            if len(parts) < 2:
                print(f"⚠️ Skipping malformed line: {line}")
                continue
            line_number = parts[0]
            mutation_str = parts[1]
            mut_dict = {}
            for mut in mutation_str.split(' '):
                wt = mut[0]
                aa = mut[-1]
                pos = int(mut[1:-1])
                mut_dict[pos] = aa
            mutations.append((line_number, mut_dict))
    return mutations

# %%
def pack(pose, posi, amino, scorefxn):
    mut_posi = ResidueIndexSelector()
    mut_posi.set_index(posi)

    nbr_selector = NeighborhoodResidueSelector()
    nbr_selector.set_focus_selector(mut_posi)
    nbr_selector.set_include_focus_in_subset(True)

    not_design = NotResidueSelector(mut_posi)

    tf = TaskFactory()
    tf.push_back(operation.InitializeFromCommandline())
    tf.push_back(operation.IncludeCurrent())
    tf.push_back(operation.NoRepackDisulfides())

    tf.push_back(operation.OperateOnResidueSubset(operation.PreventRepackingRLT(), nbr_selector, True))
    tf.push_back(operation.OperateOnResidueSubset(operation.RestrictToRepackingRLT(), not_design))

    aa_to_design = operation.RestrictAbsentCanonicalAASRLT()
    aa_to_design.aas_to_keep(amino)
    tf.push_back(operation.OperateOnResidueSubset(aa_to_design, mut_posi))

    packer = PackRotamersMover(scorefxn)
    packer.task_factory(tf)
    packer.apply(pose)

# %%
def run_mutations_from_file(pdb_path, mutation_file, output_dir, chain_id="A"):
    """
    Reads mutation instructions from a file and applies them to a PDB structure.

    Args:
        pdb_path (str): Path to the input PDB file.
        mutation_file (str): Path to the mutation file.
        output_dir (str): Directory to save the mutated PDB files.
        chain_id (str): Chain identifier used in the PDB file.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    pose = pose_from_pdb(pdb_path)
    scorefxn = get_score_function()
    results = []

    # Parse mutation file with line number and mutations
    mutations = []
    with open(mutation_file, 'r') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            parts = line.split()
            if len(parts) < 2:
                print(f"⚠️ Skipping malformed line: {line}")
                continue
            line_number = parts[0]
            mutation_str = parts[1]
            mut_dict = {}
            for mut in mutation_str.split(','):
                wt = mut[0]
                aa = mut[-1]
                try:
                    pos = int(mut[1:-1])
                    mut_dict[pos] = aa
                except ValueError:
                    print(f"⚠️ Invalid mutation format: {mut} in line {line}")
                    mut_dict = {}
                    break
            if mut_dict:
                mutations.append((line_number, mut_dict))

    for line_number, mut_dict in mutations:
        test_pose = pose.clone()
        success = True
        for pdb_res, target_aa in mut_dict.items():
            pose_res = test_pose.pdb_info().pdb2pose(chain_id, pdb_res)
            if pose_res <= 0:
                # Check the ⚠️ in the output. If your PDB file has missing residues, they will be skipped. Not a big deal, but it's better to double check.
                # We can do nothing for those missing residues. Because they are not absent from raw PDB files.
                # For me, there are several residues missing on cpmApple.
                print(f"⚠️ Skipping {line_number}: Cannot find residue {chain_id}:{pdb_res} in pose.") 
                success = False
                break
            pack(test_pose, pose_res, target_aa, scorefxn)

        if success:
            energy = scorefxn(test_pose)
            out_pdb = os.path.join(output_dir, f"{line_number}.pdb")
            test_pose.dump_pdb(out_pdb)
            results.append((line_number, energy))
            print(f"✅ Line {line_number}: Energy = {energy:.2f}")

    # Save all energy results to CSV
    csv_file = os.path.join(output_dir, "mutation_energy_results.csv")
    with open(csv_file, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(["LineNumber", "Energy"])
        writer.writerows(results)

# %%
def main():
    # Initialize PyRosetta
    init()

    # Path to your relaxed PDB file
    pdb_path = "/home/shuyu/Development/PyRosetta/prepared_structures/4I2Y_relaxed_chain_A.pdb" 
    # Path to your mutation list file, it should contain lines like: 1 A123A A124G， it should be a .txt file
    # This notebook suppports multiple mutations, like: 1 A123A A124G. Use a space to separate them.
    # The first column is the index number, the final output file will be named by this number.
    mutation_file = "/home/shuyu/Development/PyRosetta/variants_list.txt" 
    # Output directory for mutated structures
    output_dir = "/home/shuyu/Development/PyRosetta/mutated_structures"
    # Chain ID in the PDB file, it dependes on you, if you have a multi-chain PDB file, you can specify the chain ID here
    run_mutations_from_file(pdb_path, mutation_file, output_dir, chain_id="A")


if __name__ == "__main__":
    main()
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2025 [Rosetta PyRosetta4.conda.ubuntu.cxx11thread.serialization.Ubuntu.python313.Release 2025.06+release.029c6a159b896477003a14f78f472d4cd2cead46 2025-02-04T15:14:13] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.conda.ubuntu.cxx11thread.serialization.Ubuntu.python313.Release r394 2025.06+release.029c6a159b 029c6a159b896477003a14f78f472d4cd2cead46 http://www.pyrosetta.org 2025-02-04T15:14:13
# core.init: Rosetta extras: [cxx11thread, serialization]
# core.init: command: PyRosetta -ex1 -ex2aro -database /home/shuyu/anaconda3/envs/PyRosetta/lib/python3.13/site-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-2030031052 seed_offset=0 real_seed=-2030031052 thread_index=0
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-2030031052 RG_type=mt19937
# core.chemical.GlobalResidueTypeSet: Finished initializing fa_standard residue type set.  Created 985 residue types
# core.chemical.GlobalResidueTypeSet: Total time to initialize 1.06285 seconds.
# core.import_pose.import_pose: File '/home/shuyu/Development/PyRosetta/prepared_structures/4I2Y_relaxed_chain_A.pdb' automatically determined to be of type PDB
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.scoring.etable: Starting energy table calculation
# core.scoring.etable: smooth_etable: changing atr/rep split to bottom of energy well
# core.scoring.etable: smooth_etable: spline smoothing lj etables (maxdis = 6)
# core.scoring.etable: smooth_etable: spline smoothing solvation etables (max_dis = 6)
# core.scoring.etable: Finished calculating energy tables.
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBPoly1D.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBFadeIntervals.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBEval.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/DonStrength.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/AccStrength.csv
# basic.io.database: Database file opened: scoring/score_functions/rama/fd/all.ramaProb
# basic.io.database: Database file opened: scoring/score_functions/rama/fd/prepro.ramaProb
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.all.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.gly.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.pro.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.valile.txt
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/P_AA
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/P_AA_n
# core.scoring.P_AA: shapovalov_lib::shap_p_aa_pp_smooth_level of 1( aka low_smooth ) got activated.
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/shapovalov/10deg/kappa131/a20.prop
# core.pack.task: Packer task: initialize from command line()
# basic.io.database: Database file opened: scoring/score_functions/elec_cp_reps.dat
# core.scoring.elec.util: Read 40 countpair representative atoms
# core.pack.dunbrack.RotamerLibrary: shapovalov_lib_fixes_enable option is true.
# core.pack.dunbrack.RotamerLibrary: shapovalov_lib::shap_dun10_smooth_level of 1( aka lowest_smooth ) got activated.
# core.pack.dunbrack.RotamerLibrary: Binary rotamer library selected: /home/shuyu/anaconda3/envs/PyRosetta/lib/python3.13/site-packages/pyrosetta/database/rotamer/shapovalov/StpDwn_0-0-0/Dunbrack10.lib.bin
# core.pack.dunbrack.RotamerLibrary: Using Dunbrack library binary file '/home/shuyu/anaconda3/envs/PyRosetta/lib/python3.13/site-packages/pyrosetta/database/rotamer/shapovalov/StpDwn_0-0-0/Dunbrack10.lib.bin'.
# core.pack.dunbrack.RotamerLibrary: Dunbrack 2010 library took 1.16246 seconds to load from binary
# core.pack.pack_rotamers: built 182 rotamers at 12 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# basic.thread_manager.RosettaThreadManager: Creating a thread pool of 1 threads.
# basic.thread_manager.RosettaThreadPool: Launched 0 new threads.
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 1: Energy = -1082.74
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 394 rotamers at 16 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 2: Energy = -1081.25
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 379 rotamers at 19 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 3: Energy = -1080.36
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 625 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 4: Energy = -971.99
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 617 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 5: Energy = -656.51
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 617 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 6: Energy = -535.98
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 618 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 7: Energy = -884.99
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 618 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line
positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 70: Energy = -1073.60
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 385 rotamers at 17 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 71: Energy = -1080.04
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 399 rotamers at 17 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 72: Energy = -1081.54
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 385 rotamers at 17 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 73: Energy = -1078.71
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 399 rotamers at 17 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 74: Energy = -1081.95
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 437 rotamers at 17 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 75: Energy = -1083.93
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 419 rotamers at 17 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 76: Energy = -1085.18
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 385 rotamers at 17 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 77: Energy = -1084.43
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 384 rotamers at 17 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 78: Energy = -1064.73
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 387 rotamers at 17 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 79: Energy = -1050.25
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 235 rotamers at 16 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 80: Energy = -1084.33
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 228 rotamers at 16 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 81: Energy = -1083.82
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 244 rotamers at 16 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 82: Energy = -1085.53
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 227 rotamers at 16 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 83: Energy = -1082.41
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 623 rotamers at 22 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 84: Energy = -1075.66
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 717 rotamers at 20 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 85: Energy = -1081.07
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 440 rotamers at 17 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 86: Energy = -1084.90
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 510 rotamers at 24 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 87: Energy = -1085.89
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 555 rotamers at 24 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 88: Energy = -1052.12
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 522 rotamers at 24 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 90: Energy = -984.38
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 563 rotamers at 24 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 91: Energy = -1045.00
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 742 rotamers at 21 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 92: Energy = -1079.53
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 749 rotamers at 21 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 93: Energy = -1080.16
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 588 rotamers at 23 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 94: Energy = -1079.74
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 692 rotamers at 24 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 95: Energy = -1081.67
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 740 rotamers at 24 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# ...
# core.pack.pack_rotamers: built 422 rotamers at 19 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 821: Energy = -1056.81
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 622 rotamers at 21 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 822: Energy = -1078.69
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 622 rotamers at 21 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 823: Energy = -1078.69
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 422 rotamers at 19 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 824: Energy = -1056.81
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 378 rotamers at 13 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 825: Energy = -1084.24
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 425 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 826: Energy = -1076.91
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 425 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 827: Energy = -1076.91
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 425 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 828: Energy = -1076.91
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 422 rotamers at 19 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 829: Energy = -1056.81
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 394 rotamers at 16 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 830: Energy = -1081.25
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 422 rotamers at 19 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 831: Energy = -1056.81
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 560 rotamers at 20 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 832: Energy = -1081.13
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 422 rotamers at 19 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 833: Energy = -1056.81
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 387 rotamers at 16 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 834: Energy = -1082.32
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 419 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 835: Energy = -1067.67
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 387 rotamers at 16 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 836: Energy = -1082.32
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 560 rotamers at 20 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 837: Energy = -1081.13
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 425 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 838: Energy = -1076.91
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 422 rotamers at 19 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 839: Energy = -1056.81
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 422 rotamers at 19 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 840: Energy = -1056.81
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 425 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 841: Energy = -1076.91
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 560 rotamers at 20 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 842: Energy = -1081.13
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 425 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 843: Energy = -1076.91
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 622 rotamers at 21 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 844: Energy = -1078.69
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 378 rotamers at 13 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 845: Energy = -1084.24
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 182 rotamers at 12 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 846: Energy = -1082.74
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 182 rotamers at 12 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 847: Energy = -1082.74
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 778 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 848: Energy = -1082.37
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 778 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 849: Energy = -1082.37
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 732 rotamers at 20 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 850: Energy = -1078.30
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 732 rotamers at 20 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 851: Energy = -1078.30
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 425 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 852: Energy = -1076.91
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 419 rotamers at 25 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 853: Energy = -1064.33
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 387 rotamers at 16 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 854: Energy = -1082.32
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 378 rotamers at 13 positions.
# core.pack.pack_rotamers: Requesting all available threads for interaction graph computation.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating PDInteractionGraph
# core.pack.rotamer_set.RotamerSets: Completed interaction graph pre-calculation in 1 available threads (1 had been requested).
# ✅ Line 855: Energy = -1084.24
